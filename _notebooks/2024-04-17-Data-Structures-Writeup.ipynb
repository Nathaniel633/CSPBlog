# %% [markdown]
# ---
# comments: true
# layout: post
# title: DataStructures Writeup
# type: hacks
# courses: { compsci: {week: 31} }
# ---

# %% [markdown]
# # Collections
#
# Blog Python Model code and SQLite Database.
#
# - From VSCode using SQLite3 Editor, show your unique collection/table in database, display rows and columns in the table of the SQLite database.
#
# [![DB-result.png](https://i.postimg.cc/5tpDrcBP/DB-result.png)](https://postimg.cc/4K78KSFt)
#
# Here we see the database in SQLite of the items that our integrated CPT project calls in the frontend
#
# - From VSCode model, show your unique code that was created to initialize table and create test data.
#
# [![Backend-init.png](https://i.postimg.cc/Tw5M57bC/Backend-init.png)](https://postimg.cc/YG7yJxbW)
#
# Specific to my team's CPT, this data initializes the columns for the information on each character in terms of id, class name, health, attack, range, and movement.
#
# # Lists and Dictionaries
#
# Blog Python API code and use of List and Dictionaries.
#
# - In VSCode using Debugger, show a list as extracted from database as Python objects.
#
# [![Dict.png](https://i.postimg.cc/mDjMMjG1/Dict.png)](https://postimg.cc/ygJkCFx7)
#
# Here is the python code of which I extract entries from 'self' a python function using a breakpoint in debugger.
#
# - In VSCode use Debugger and list, show two distinct example examples of dictionaries, show Keys/Values using debugger.
#
# [![Multiple-dicts.png](https://i.postimg.cc/XYZ9B9JQ/Multiple-dicts.png)](https://postimg.cc/Snhnw2cM)
#
# Here we have another example of a dictionary where each of the inputs of the character are stored using get functions.
#
# # APIs and JSON
#
# Blog Python API code and use of Postman to request and respond with JSON.
#
# - In VSCode, show Python API code definition for request and response using GET, POST, UPDATE methods. Discuss algorithmic condition used to direct request to appropriate Python method based on request method.
#
# - In VSCode, show algorithmic conditions used to validate data on a POST condition.
#
# - In Postman, show URL request and Body requirements for GET, POST, and UPDATE methods.
#
# - In Postman, show the JSON response data for 200 success conditions on GET, POST, and UPDATE methods.
#
# - In Postman, show the JSON response for error for 400 when missing body on a POST request.
#
# - In Postman, show the JSON response for error for 404 when providing an unknown user ID to a UPDATE request.
#
# # Frontend
#
# Blog JavaScript API fetch code and formatting code to display JSON.
#
# - In Chrome inspect, show response of JSON objects from fetch of GET, POST, and UPDATE methods.
#
# [![frontend-better-fetch.png](https://i.postimg.cc/vmwWK7pq/frontend-better-fetch.png)](https://postimg.cc/bZLDDnYk)
#
# Here we store the fetch in an away response.
#
# - In the Chrome browser, show a demo (GET) of obtaining an Array of JSON objects that are formatted into the browsers screen.
#
# [![Frontend-fetch.png](https://i.postimg.cc/mk28vhSJ/Frontend-fetch.png)](https://postimg.cc/wyZXJqZQ)
#
# We see here the main game screen with the character chosen previously on-screen and it's specific attributes to the character class using GET JSON objects from fetch.
#
# - In JavaScript code, describe fetch and method that obtained the Array of JSON objects.
#
# [![GET-Script.png](https://i.postimg.cc/g29TgV7B/GET-Script.png)](https://postimg.cc/4m5Pd9sz)
#
# In the JavaScript, here we have the fetch GET method receiving an array of the CurrentChar stats to perform the damage calculations.
#
# - In JavaScript code, show code that performs iteration and formatting of data into HTML.
#
# [![JS-HTML.png](https://i.postimg.cc/Pxvt6m8L/JS-HTML.png)](https://postimg.cc/ZBZtnvHZ)
#
# In this JavaScript as part of the Character Creation page, we see the stats of the current character being formatted into an array for the HTML to access to display in a table on the character selection screen.
#
# - In the Chrome browser, show a demo (POST or UPDATE) gathering and sending input and receiving a response that show update. Repeat this demo showing both success and failure.
#
# [![Site-success.png](https://i.postimg.cc/CKg8jxBp/Site-success.png)](https://postimg.cc/Sngj4qfg)
#
# Here is a successful example of me previously on position 3 and moving to position 6, with this move being logged in the console as well as a JavaScript alert warning me the enemy has also moved.
#
# [![Site-failure.png](https://i.postimg.cc/5N1NqKbT/Site-failure.png)](https://postimg.cc/YjnHt34z)
#
# However if you input a space not adjacent to you (ex. me being on space 6 and requesting to move to space 1), you will get an alert saying that your input is not valid.
#
#  - In JavaScript code, show and describe code that handles success. Describe how code shows success to the user in the Chrome Browser screen.
#
# [![js-success.png](https://i.postimg.cc/tgV8ZyZ6/js-success.png)](https://postimg.cc/mcBmJvSZ)
#
# Here we see our JavaScript riddled with console logs to notify the player that the enemy has moved and where it has moved to once they player moves successfully.
#
# - In JavaScript code, show and describe code that handles failure. Describe how the code shows failure to the user in the Chrome Browser screen.
#
# [![js-failure.png](https://i.postimg.cc/rwzYtc0J/js-failure.png)](https://postimg.cc/zyZk9skb)
#
# However here, at the bottom of the previous JavaScript segment, we have a line to alert the player of an invalid input if something goes wrong along the way, as well as a check for player and enemy positions.
